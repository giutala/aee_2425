# %%
from pvodataset import PVODataset, UDFClass, QCfunc
import pandas as pd

# %%
from pvodataset import PVODataset, UDFClass, QCfunc
import pandas as pd

# load PV output Dataset
pvod = PVODataset(path="../datasets/",timezone="UTC+8")

# load selected station original data
# pd.set_option('display.max_columns', 5)

ori_data = pvod.read_ori_data(station_id=3)
ori_data
# Out:
# Welcome to PVODataset (PVOD).

# %%
# load selected station original data
# pd.set_option('display.max_columns', 5)

ori_data = pvod.read_ori_data(station_id=3)
ori_data
# Out:
#                       date_time  nwp_globalirrad  nwp_directirrad  \
# 0     2019-01-12 00:00:00+08:00              0.0              0.0
# 1     2019-01-12 00:15:00+08:00              0.0              0.0
# 2     2019-01-12 00:30:00+08:00              0.0              0.0
# 3     2019-01-12 00:45:00+08:00              0.0              0.0
# 4     2019-01-12 01:00:00+08:00              0.0              0.0
# ...                         ...              ...              ...
# 14683 2019-06-13 22:45:00+08:00              0.0              0.0
# 14684 2019-06-13 23:00:00+08:00              0.0              0.0
# 14685 2019-06-13 23:15:00+08:00              0.0              0.0
# 14686 2019-06-13 23:30:00+08:00              0.0              0.0
# 14687 2019-06-13 23:45:00+08:00              0.0              0.0
#
#        nwp_temperature  nwp_humidity  nwp_windspeed  nwp_winddirection  \
# 0                -0.07         44.66           1.50             234.97
# 1                -0.13         45.23           1.59             238.49
# 2                -0.15         45.60           1.67             246.38
# 3                -0.17         45.86           1.77             255.51
# 4                -0.21         46.08           1.88             262.02
# ...                ...           ...            ...                ...
# 14683            24.45         61.99           4.00             327.25
# 14684            24.24         62.48           4.08             331.59
# 14685            24.08         62.74           4.02             334.14
# 14686            23.95         62.97           3.94             334.80
# 14687            23.82         63.31           3.85             333.20
#
#        nwp_pressure  lmd_totalirrad  lmd_diffuseirrad  lmd_temperature  \
# 0            989.14               0               0.0        -2.800000
# 1            989.14               0               0.0        -2.800000
# 2            989.25               0               0.0        -2.800000
# 3            989.31               0               0.0        -3.900000
# 4            989.08               0               0.0        -3.900000
# ...             ...             ...               ...              ...
# 14683        974.82               0               0.0        21.799999
# 14684        974.96               0               0.0        20.700001
# 14685        975.13               0               0.0        20.700001
# 14686        975.28               0               0.0        20.700001
# 14687        975.47               0               0.0        20.700001
#
#        lmd_pressure  lmd_winddirection  lmd_windspeed  power
# 0        988.500000                 48            1.0    0.0
# 1        988.500000                138            1.0    0.0
# 2        988.500000                 40            1.0    0.0
# 3        988.500000                130            1.0    0.0
# 4        988.500000                158            1.0    0.0
# ...             ...                ...            ...    ...
# 14683    972.799988                 72            0.8    0.0
# 14684    972.799988                350            0.7    0.0
# 14685    972.799988                 71            1.0    0.0
# 14686    972.799988                104            0.0    0.0
# 14687    972.799988                163            2.4    0.0
#
# [14688 rows x 15 columns]
